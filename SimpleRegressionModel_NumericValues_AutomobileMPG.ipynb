# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
automobile_df = pd.read_csv('auto-mpg-processed.csv')

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 4    34.7          4         105.0          63    2215          14.9   39
# 274  12.0          8         400.0         167    4906          12.5   47
# 337  26.0          4          98.0          90    2265          15.5   47
# 221  35.0          4          72.0          69    1613          18.0   49
# 191  14.0          8         400.0         175    4464          11.5   49

# %%
from sklearn.model_selection import train_test_split

X = automobile_df[['horsepower']]
y = automobile_df['mpg']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape, y_train.shape
# Out:
# ((313, 1), (313,))

# %%
X_test.shape,y_test.shape
# Out:
# ((79, 1), (79,))

# %%
X_train.sample(5)
# Out:
#      horsepower
# 65           95
# 207          75
# 333          83
# 21           95
# 151          85

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize=True).fit(X_train, y_train)

# %%
y_pred = linear_model.predict(X_test)

# %%
print 'Training score: ', linear_model.score(X_train, y_train)
# Out:
# Training score:  0.6010537766299315

# %%
from sklearn.metrics import r2_score

print 'Testing score: ', r2_score(y_test, y_pred)
# Out:
# Testing score:  0.6185906371551433

# %%
fig, ax = plt.subplots(figsize = (12,8))

plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='r')
plt.xlabel('Horsepower')

plt.ylabel('Miles per gallon')
plt.show()

# %%
X = automobile_df[['age']]
y = automobile_df['mpg']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

linear_model = LinearRegression(normalize=True).fit(X_train, y_train)

print 'Training score: ', linear_model.score(X_train, y_train)

y_pred = linear_model.predict(X_test)

print 'Testing score: ', r2_score(y_test, y_pred)
# Out:
# Training score:  0.31682465315504504
# Testing score:  0.4322868947900692

# %%
fig, ax = plt.subplots(figsize = (12,8))

plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='r')
plt.xlabel('Age')

plt.ylabel('Miles per gallon')
plt.show()

# %%
#Using Linear Regression with Multiple features
X = automobile_df[['displacement', 'horsepower', 'weight']]
y = automobile_df['mpg']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
linear_model = LinearRegression(normalize=True).fit(X_train, y_train)

# %%
print 'Training score: ', linear_model.score(X_train, y_train)
# Out:
# Training score:  0.7003122649399631

# %%
y_pred = linear_model.predict(X_test)

# %%
print 'Testing score: ', r2_score(y_test, y_pred)
# Out:
# Testing score:  0.7249622797250814

# %%
predictors = X_train.columns
coef = pd.Series(linear_model.coef_, predictors).sort_values()

print coef
# Out:
# horsepower     -0.057027
# weight         -0.005139
# displacement   -0.002318
# dtype: float64

# %%
plt.figure(figsize = (20,10))

plt.plot(y_pred, label = 'Predicted')
plt.plot(y_test.values, label = 'Actual')

plt.ylabel('Miles per gallon')

plt.legend()

plt.show()

# %%
# Using more features with our Linear Regression model
X = automobile_df[['displacement', 'horsepower', 'weight', 'acceleration', 'cylinders']]
y = automobile_df['mpg']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
linear_model = LinearRegression(normalize=True).fit(X_train, y_train)

# %%
print 'Training score: ', linear_model.score(X_train, y_train)
# Out:
# Training score:  0.7128558310375797

# %%
predictors = X_train.columns
coef = pd.Series(linear_model.coef_, predictors).sort_values()

print coef
# Out:
# cylinders      -0.262790
# horsepower     -0.040533
# acceleration   -0.016457
# weight         -0.005342
# displacement   -0.002513
# dtype: float64

# %%
y_pred = linear_model.predict(X_test)

# %%
print 'Testing score: ', r2_score(y_test, y_pred)
# Out:
# Testing score:  0.6848241012099623

# %%
plt.figure(figsize = (20,10))

plt.plot(y_pred, label = 'Predicted')
plt.plot(y_test.values, label = 'Actual')

plt.ylabel('Miles per gallon')

plt.legend()

plt.show()
